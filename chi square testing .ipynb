# %%
import numpy as np 
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder 
le=LabelEncoder()
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Nisha\OneDrive\Desktop\project data in excel.csv")
data
# Out:
#      Gender  Age_group   First_time_voter  responsible_voter   \
# 0      Male           40                No                Yes
# 1    Female           22                No                Yes
# 2    Female           22                No                Yes
# 3    Female           21                No                Yes
# 4    Female           25                No                Yes
# ..      ...          ...               ...                ...
# 515  Female           18               Yes                Yes
# 516    Male           31               Yes                Yes
# 517  Female           38               Yes                Yes
# 518  Female           32               Yes                Yes
# 519    Male           18               Yes                Yes
#
#     Women_Empowerment _in_Parliament Womens_Role_in_Elections  \
# 0                                Yes                       No
# 1                                Yes                      Yes
# ...

# %%
data.isnull().sum()
# Out:
# Gender                                  0
# Age_group                               0
# First_time_voter                        0
# responsible_voter                       0
# Women_Empowerment _in_Parliament        0
# Womens_Role_in_Elections                0
# Candidates_Education_Expectations       0
# Portfolio_Specialization                0
# Preference_for_Young_Candidates         0
# New_Central_Ministry_Departments        0
# Focus_on_Rural_Development              0
# Priority_areas_for_MPs                  0
# Increase_Women_MPs_for_Womens_Issues    0
# Policy_Maker_Training_Program           0
# Polity_as_a_Compulsory_Subject          0
# Avoid_Nepotism_in_Ticket_Allocation     0
# Your_Voting_Preference                  0
# Preferred_Government_or_Candidate       0
# Encouraging_Voting_for_Stability        0
# Expertise_Needed_in_New_Parliament      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in data.columns:
    if col != 'Age_group':  
        data[col] = le.fit_transform(data[col])

# %%
from scipy.stats import chi2_contingency
# Example1: Chi-square test between 'Gender' and Women_Empowerment _in_Parliament
contingency_table = pd.crosstab(data['Gender'], data["Women_Empowerment _in_Parliament"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 3.496110704464853
# P-Value: 0.061513131929443673

# %%
# Example2: Chi-square test between 'Gender' and New_Central_Ministry_Departments
contingency_table = pd.crosstab(data['Gender'], data["New_Central_Ministry_Departments "] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 3.0041437097043935
# P-Value: 0.22266834541520095

# %%
# Example3: Chi-square test between 'Gender' and Preferred_Government_or_Candidate
contingency_table = pd.crosstab(data['Gender'], data["Preferred_Government_or_Candidate"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 0.7901140283232316
# P-Value: 0.37406564806842446

# %%
# Example4: Chi-square test between 'Gender' and Focus_on_Rural_Development
contingency_table = pd.crosstab(data['Gender'], data["Focus_on_Rural_Development"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 0.8975496356900533
# P-Value: 0.34343959464568363

# %%
# Example5: Chi-square test between 'Gender' and Womens_Role_in_Elections
contingency_table = pd.crosstab(data['Gender'], data["Womens_Role_in_Elections"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 9.875213714556404
# P-Value: 0.0016752013794625266

# %%
# Example6: Chi-square test between 'Gender' and Preference_for_Young_Candidates
contingency_table = pd.crosstab(data['Gender'], data["Preference_for_Young_Candidates"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 9.37439193840511
# P-Value: 0.009212482056500751

# %%
# Example7: Chi-square test between 'Gender' and Portfolio_Specialization
contingency_table = pd.crosstab(data['Gender'], data["Portfolio_Specialization"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 4.1011420420358125
# P-Value: 0.04285425727773295

# %%
# Example8: Chi-square test between 'Gender' and Policy_Maker_Training_Program
contingency_table = pd.crosstab(data['Gender'], data["Policy_Maker_Training_Program"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 1.4252299672359798
# P-Value: 0.23254449060603008

# %%
# Example9: Chi-square test between 'Gender' and Avoid_Nepotism_in_Ticket_Allocation
contingency_table = pd.crosstab(data['Gender'], data["Avoid_Nepotism_in_Ticket_Allocation"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 3.816302478652752
# P-Value: 0.05075612869094296

# %%
# Example10: Chi-square test between 'Gender' and Your_Voting_Preference
contingency_table = pd.crosstab(data['Gender'], data["Your_Voting_Preference"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 4.489450979407826
# P-Value: 0.2132331681941576

# %%
# Example11: Chi-square test between 'Gender' and Expertise_Needed_in_New_Parliament
contingency_table = pd.crosstab(data['Gender'], data["Expertise_Needed_in_New_Parliament"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 5.901315648041695
# P-Value: 0.11651139687534062

# %%
# Example12: Chi-square test between 'Gender' and  Priority_areas_for_MPs
contingency_table = pd.crosstab(data['Gender'], data["Priority_areas_for_MPs"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 26.135889737054278
# P-Value: 8.932560934145799e-06

# %%
# Example13: Chi-square test between 'Gender' and  Candidates_Education_Expectations
contingency_table = pd.crosstab(data['Gender'], data["Candidates_Education_Expectations"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 2.5731969464703566
# P-Value: 0.46220785585746926

# %%
# Example14: Chi-square test between 'Gender' and  Increase_Women_MPs_for_Womens_Issues
contingency_table = pd.crosstab(data['Gender'], data["Increase_Women_MPs_for_Womens_Issues"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 2.2973167154714673
# P-Value: 0.1295977124109866

# %% [markdown]
# ####   Gender and Womens_Role_in_Elections ,Preference_for_Young_Candidates ,Priority_areas_for_MPs ,Portfolio_Specialization
# ####   These are expectation is dependent on the gender of the candidate

# %%
contingency_table = pd.crosstab(data['Age_group  '], data["Candidates_Education_Expectations"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 241.88971859217602
# P-Value: 8.968992764093687e-05

# %%
contingency_table = pd.crosstab(data['Age_group  '], data["Preference_for_Young_Candidates"] )
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p_value}")
# Out:
# Chi-Square Statistic: 152.04408875079943
# P-Value: 0.004925195765916063

# %%
# !pip install kmodes

# %%
import pandas as pd
import numpy as np
from kmodes.kmodes import KModes
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv(r"C:\Users\Nisha\OneDrive\Desktop\project data in excel.csv")

# Handling missing values (if any)
data.fillna("Unknown", inplace=True)

# Convert categorical data to numerical using Label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in data.columns:
    data[col] = le.fit_transform(data[col])

# Elbow Method to find optimal number of clusters
cost = []
K = range(1, 10)  # Trying 1 to 10 clusters

for k in K:
    km = KModes(n_clusters=k, init="Cao", n_init=5, verbose=0)
    km.fit_predict(data)
    cost.append(km.cost_)

# Plot the Elbow Graph
plt.figure(figsize=(8,5))
plt.plot(K, cost, marker='o', linestyle='dashed', color='b')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Cost')
plt.title('Elbow Method for Optimal K')
plt.show()

# Choosing optimal K (from elbow point) and fitting the model
optimal_k = 3  # Change this based on the Elbow method result
kmodes = KModes(n_clusters=optimal_k, init="Cao", n_init=5, verbose=1)
clusters = kmodes.fit_predict(data)

# Add cluster labels to dataset
data['Cluster'] = clusters

# Display Cluster Counts
print(data['Cluster'].value_counts())

# Visualize Cluster Distribution
plt.figure(figsize=(8,5))
sns.countplot(x=data['Cluster'], palette="viridis")
plt.xlabel("Cluster")
plt.ylabel("Count")
plt.title("Cluster Distribution")
plt.show()

# Cluster-wise Summary
cluster_summary = data.groupby("Cluster").mean()
print(cluster_summary)

# Save the clustered dataset
data.to_csv("Clustered_Survey_Data.csv", index=False)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 55, cost: 3485.0
# Run 1, iteration: 2/100, moves: 1, cost: 3485.0
# Cluster
# 0    353
# 2     85
# 1     82
# Name: count, dtype: int64
#            Gender  Age_group    First_time_voter   responsible_voter   \
# Cluster
# 0        0.388102    15.416431           0.266289            0.855524
# 1        0.621951    21.621951           0.170732            0.585366
# 2        0.705882    11.964706           0.564706            0.870588
#
#          Women_Empowerment _in_Parliament  Womens_Role_in_Elections  \
# Cluster
# 0                                0.722380                  0.866856
# 1                                0.621951                  0.463415
# 2                                0.329412                  0.811765
#
# ...
